# %%
from ultralytics import YOLO
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import cv2

# %%
model=YOLO("best_recyclable_non_recyclable.pt")

# %%
results=model.predict(source="0", show=True)

key_pressed=cv2.waitKey(1) & 0xFF
if key_pressed==ord('q'):
    cv2.destroyAllWindows()
    cv2.waitKey(1)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1280x720 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x800 1 non-recyclable, 808.3ms
# 0: 480x800 1 non-recyclable, 479.7ms
# 0: 480x800 1 non-recyclable, 404.5ms
# 0: 480x800 1 non-recyclable, 449.3ms
# 0: 480x800 1 non-recyclable, 375.0ms
# 0: 480x800 1 non-recyclable, 409.3ms
# 0: 480x800 1 recyclable, 2 non-recyclables, 380.2ms
# 0: 480x800 2 non-recyclables, 370.1ms
# 0: 480x800 2 non-recyclables, 334.7ms
# ...
